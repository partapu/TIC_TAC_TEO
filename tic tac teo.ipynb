# %%
import pandas as pd

import numpy as np

# %%
data=pd.read_csv("C:/Users/preetham/Desktop/tic-tac-toe_csv.csv")

# %%
data.head()
# Out:
#   TL TM TR ML MM MR BL BM BR  class
# 0  x  x  x  x  o  o  x  o  o   True
# 1  x  x  x  x  o  o  o  x  o   True
# 2  x  x  x  x  o  o  o  o  x   True
# 3  x  x  x  x  o  o  o  b  b   True
# 4  x  x  x  x  o  o  b  o  b   True

# %%
data.TL.value_counts()
# Out:
# x    418
# o    335
# b    205
# Name: TL, dtype: int64

# %%
def handle_non_numerical_data(df):
    columns = df.columns.values

    for column in columns:
        text_digit_vals = {}
        def convert_to_int(val):
            return text_digit_vals[val]

        if df[column].dtype != np.int64 and df[column].dtype != np.float64:
            column_contents = df[column].values.tolist()
            unique_elements = set(column_contents)
            x = 0
            for unique in unique_elements:
                if unique not in text_digit_vals:
                    text_digit_vals[unique] = x
                    x+=1

            df[column] = list(map(convert_to_int, df[column]))

    return df

# %%
handle_non_numerical_data(df)
# Out:
#      TL  TM  TR  ML  MM  MR  BL  BM  BR  class
# 0     2   2   2   2   0   0   2   0   0      1
# 1     2   2   2   2   0   0   0   2   0      1
# 2     2   2   2   2   0   0   0   0   2      1
# 3     2   2   2   2   0   0   0   1   1      1
# 4     2   2   2   2   0   0   1   0   1      1
# 5     2   2   2   2   0   0   1   1   0      1
# 6     2   2   2   2   0   1   0   0   1      1
# 7     2   2   2   2   0   1   0   1   0      1
# 8     2   2   2   2   0   1   1   0   0      1
# 9     2   2   2   2   1   0   0   0   1      1
# 10    2   2   2   2   1   0   0   1   0      1
# 11    2   2   2   2   1   0   1   0   0      1
# 12    2   2   2   0   2   0   2   0   0      1
# 13    2   2   2   0   2   0   0   2   0      1
# 14    2   2   2   0   2   0   0   0   2      1
# 15    2   2   2   0   2   0   0   1   1      1
# 16    2   2   2   0   2   0   1   0   1      1
# 17    2   2   2   0   2   0   1   1   0      1
# 18    2   2   2   0   2   1   0   0   1      1
# 19    2   2   2   0   2   1   0   1   0      1
# 20    2   2   2   0   2   1   1   0   0      1
# 21    2   2   2   0   0   2   2   0   0      1
# 22    2   2   2   0   0   2   0   2   0      1
# 23    2   2   2   0   0   2   0   0   2      1
# 24    2   2   2   0   0   2   0   1   1      1
# 25    2   2   2   0   0   2   1   0   1      1
# 26    2   2   2   0   0   2   1   1   0      1
# 27    2   2   2   0   0   1   2   0   1      1
# 28    2   2   2   0   0   1   2   1   0      1
# 29    2   2   2   0   0   1   0   2   1      1
# ..   ..  ..  ..  ..  ..  ..  ..  ..  ..    ...
# 928   1   1   2   2   2   1   0   0   0      0
# 929   1   1   2   2   1   2   0   0   0      0
# 930   1   1   2   0   0   0   2   2   1      0
# 931   1   1   2   0   0   0   2   1   2      0
# 932   1   1   2   0   0   0   1   2   2      0
# 933   1   1   2   1   2   2   0   0   0      0
# 934   1   1   0   2   2   0   2   1   0      0
# 935   1   1   0   2   2   0   1   2   0      0
# 936   1   1   0   2   0   2   0   2   1      0
# 937   1   1   0   2   0   2   0   1   2      0
# 938   1   1   0   2   0   1   0   2   2      0
# 939   1   1   0   2   1   0   2   2   0      0
# 940   1   1   0   1   2   0   2   2   0      0
# 941   1   1   0   1   0   2   0   2   2      0
# 942   2   2   0   0   2   2   2   0   0      0
# 943   2   2   0   0   0   2   2   2   0      0
# 944   2   2   0   0   0   2   2   0   2      0
# 945   2   0   2   2   2   0   0   2   0      0
# 946   2   0   2   2   0   2   0   2   0      0
# 947   2   0   2   2   0   0   0   2   2      0
# 948   2   0   2   0   2   2   0   2   0      0
# 949   2   0   2   0   0   2   2   2   0      0
# 950   2   0   0   0   2   2   2   2   0      0
# 951   0   2   2   2   2   0   0   0   2      0
# 952   0   2   2   2   0   0   2   0   2      0
# 953   0   2   2   2   0   0   0   2   2      0
# 954   0   2   0   2   2   0   2   0   2      0
# 955   0   2   0   2   0   2   2   0   2      0
# 956   0   2   0   0   2   2   2   0   2      0
# 957   0   0   2   2   2   0   0   2   2      0
#
# [958 rows x 10 columns]

# %%
import seaborn as sn

# %%
sn.heatmap(df.isnull(),yticklabels=False,cbar=False,cmap='viridis')

# %%
X=df.drop("class",axis=1)
Y=df['class']

# %%
from sklearn.cross_validation import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(X,Y,test_size=0.3,random_state=42)

# %%
USING LOGISTIC REGRESSION

# %%
from sklearn.linear_model import LogisticRegression

# %%
logistic=LogisticRegression()

# %%
logistic.fit(x_train,y_train)
# Out:
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='ovr', n_jobs=1,
#           penalty='l2', random_state=None, solver='liblinear', tol=0.0001,
#           verbose=0, warm_start=False)

# %%
prediction=logistic.predict(x_test)

# %%
from sklearn.metrics import confusion_matrix

# %%
confusion_matrix(y_test,prediction)
# Out:
# array([[ 51,  44],
#        [  7, 186]], dtype=int64)

# %%
from sklearn.metrics import accuracy_score

# %%
accuracy_score(y_test,prediction)
# Out:
# 0.8229166666666666

# %% [markdown]
# USING KNN

# %%
from sklearn.neighbors import KNeighborsClassifier

# %%
knn=KNeighborsClassifier(n_neighbors=1)

# %%
knn.fit(x_test,y_test)
# Out:
# KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#            metric_params=None, n_jobs=1, n_neighbors=1, p=2,
#            weights='uniform')

# %%
prediction=knn.predict(x_test)
type(prediction)
# Out:
# numpy.ndarray

# %%
from sklearn.metrics import accuracy_score

# %%
accuracy_score(y_test,prediction)
# Out:
# 1.0

# %% [markdown]
# FINDING BEST VALUE OF K

# %%
l=[]
for i in range(1,50):
    knn=KNeighborsClassifier(n_neighbors=i)
    knn.fit(x_train,y_train)
    prediction=knn.predict(x_test)
    l.append(np.mean(y_test !=prediction))

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(10,6))

# %%
plt.plot(range(1,50),l,color="blue",linestyle="dashed",marker="o",markerfacecolor="red",markersize=10)
